# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# /opt/homebrew/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
config_file = '../configs/mask_rcnn/mask_rcnn_r50_fpn_1x_coco.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
checkpoint_file = '../checkpoints/laboro_tomato_48ep.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cpu')
# Out:
# load checkpoint from local path: ../checkpoints/laboro_tomato_48ep.pth

# %%
# test a single image
img = 'raw_IMG_1223.png'
result = inference_detector(model, img)

# %%
image = mpimg.imread(img)
plt.figure(figsize = (10,15))
plt.imshow(image, aspect='auto')
plt.show()

# %%
# show the results
show_result_pyplot(model, img, result, out_file='output_'+img)
